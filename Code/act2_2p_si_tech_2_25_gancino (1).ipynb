# %% [markdown]
# #Categorical data encoding

# %% [markdown]
# ##1. Import libraries and load dataset

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df = pd.read_csv('DatasetLibros.csv')
df
# Out:
#                                         libro            autor  \
# 0          Aplicaciones modernas de Ambiental  Esteban Aguilar
# 1     Sistematizacion de Ciencias de la salud     Carlos Pérez
# 2                  Conocimientos de Ambiental    Nuria Alvarez
# 3                Sistematizacion de Filosofía     Sergio Gomez
# 4           Pilares de la ingeniería Mecanica    Carlos Javier
# ...                                       ...              ...
# 2631          Procesos de la ingeniería Artes   Ricardo Gualán
# 2632      Pilares de la ingeniería Industrial    Nuria Alvarez
# 2633                   Principios de Mecanica  Alfons Gonzalez
# 2634                   Fundamentos de Derecho     María Torres
# 2635     Conocimientos de Hoteleria y turismo    Luis Martínez
#
#             editorial  anio_publicacion  num_paginas  formato  \
# 0           Alfaomega              2001          294   Físico
# 1     Cambridge Press              2022          592  Digital
# 2            Springer              2001          759   Físico
# 3           Alfaomega              2015          712   Físico
# 4         McGraw-Hill              2012          328   Físico
# ...               ...               ...          ...      ...
# 2631         Springer              2014          740   Físico
# 2632      McGraw-Hill              2004          546   Físico
# 2633        Alfaomega              2011          676  Digital
# 2634      McGraw-Hill              2015          510   Físico
# 2635     Panamericana              2004          261   Físico
#
#                  categoria  rating  popularidad_libro
# 0                Ambiental    3.01                  2
# 1     Ciencias de la salud    1.25                  1
# 2                Ambiental    4.14                  6
# 3                Filosofía    1.37                 10
# 4                 Mecanica    1.24                  1
# ...                    ...     ...                ...
# 2631                 Artes    4.84                  5
# 2632            Industrial    1.47                  9
# 2633              Mecanica    1.10                  5
# 2634               Derecho    1.96                  9
# 2635   Hoteleria y turismo    2.60                  1
#
# [2636 rows x 9 columns]

# %% [markdown]
# -------------
# ##2. One-hot encoding

# %% [markdown]
# Categorical columns to be transformed

# %%
cat_cols = ["autor", "editorial", "formato", "categoria", "libro"]

# %%
df_ohe = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %% [markdown]
# -------------
# ##3. Label encoding

# %%
df_le = df.copy()
for col in cat_cols:
    le = LabelEncoder()
    df_le[col] = le.fit_transform(df_le[col])

# %% [markdown]
# -------------
# ##4. Target encoding

# %%
df_te = df.copy()
for col in cat_cols:
    means = df.groupby(col)["rating"].mean()
    df_te[col] = df_te[col].map(means)

# %% [markdown]
# -------------
# ##5.1. Training without techniques

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# %% [markdown]
# Use original dataset

# %%
df_original = df.copy()

# %% [markdown]
# Select only numeric columns

# %%
numeric_cols = df_original.select_dtypes(include=["int64", "float64"]).columns.tolist()
numeric_cols = [c for c in numeric_cols if c != "rating"]

X_no_encoding = df_original[numeric_cols]
y_no_encoding = df_original["rating"]

# %%
X_train_A, X_test_A, y_train_A, y_test_A = train_test_split(
    X_no_encoding, y_no_encoding, test_size=0.2, random_state=42)

model_A = LinearRegression()
model_A.fit(X_train_A, y_train_A)

pred_A = model_A.predict(X_test_A)

# %%
print("R²:", r2_score(y_test_A, pred_A))
print("MSE:", mean_squared_error(y_test_A, pred_A))
print("RMSE:", np.sqrt(mean_squared_error(y_test_A, pred_A)))

# %% [markdown]
# -------------
# ##5.2. Training with techniques - Using one-hot encoding and feature scalling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# %% [markdown]
# Use encoded dataset

# %%
df_encoded = df_ohe.copy()

# %%
X_B = df_encoded.drop(columns=["rating"])
y_B = df_encoded["rating"]

pipeline_B = Pipeline([
    ("scaler", StandardScaler()),
    ("model", LinearRegression())
])

X_train_B, X_test_B, y_train_B, y_test_B = train_test_split(
    X_B, y_B, test_size=0.2, random_state=42)

pipeline_B.fit(X_train_B, y_train_B)

pred_B = pipeline_B.predict(X_test_B)
